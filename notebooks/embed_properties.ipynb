# %%
import requests
import chromadb

from fastembed import TextEmbedding

# %%
query = """SELECT ?property ?propertyLabel ?propertyDesc WHERE {
    # ?property a wikibase:Property .
    SERVICE wikibase:label {
      bd:serviceParam wikibase:language "en" .
      # ?property schema:description ?propertyDesc .
      # ?property rdfs:label ?propertyLabel .
   }
 }"""

url = 'https://query.wikidata.org/sparql'

r = requests.get(url, params = {'query': query, 'format': 'json'})

data = r.json()

# %%
data["results"]["bindings"][0]["propertyDesc"]
# Out:
# {'xml:lang': 'en',
#  'type': 'literal',
#  'value': 'head of the executive power of this town, city, municipality, state, country, or other governmental body'}

# %%
# extract into 3 lists : property, propertyLabel, propertyDesc

props = []
labels = []
descs = []

for item in data["results"]["bindings"]:
    if "propertyDesc" not in item:
        print(item)
        descs.append("")
    else:
        descs.append(item['propertyDesc']['value'])

    props.append(item['property']['value'])
    labels.append(item['propertyLabel']['value'])

# %%
model = TextEmbedding()
# Out:
# Fetching 9 files: 100%|██████████| 9/9 [00:00<00:00, 41896.49it/s]

# %%
def prepare_embeddings(props, labels, descs):

    emb_prompts = [
        f"Wikidata property: {label} ({desc})" for label, desc in zip(labels, descs)
    ]

    embeddings = model.embed(emb_prompts)

    return embeddings

embeddings = list(prepare_embeddings(props, labels, descs))

# %%
client = chromadb.PersistentClient(path="../props_vector_db")

# %%
colection = client.create_collection("wikidata_properties")
# colection = client.get_collection("wikidata_properties")

# %%
embeddings[0].tolist()
# Out:
# [-0.006174369249492884,
#  0.005588064435869455,
#  0.06050939857959747,
#  -0.054765526205301285,
#  0.037459246814250946,
#  0.01666261814534664,
#  0.1484055370092392,
#  -0.04147284850478172,
#  -0.022853853181004524,
#  0.061576809734106064,
#  -0.03567548468708992,
#  -0.06317933648824692,
#  -0.03275105729699135,
#  -0.003169655567035079,
#  -0.029477577656507492,
#  0.007349770050495863,
#  -0.03480827435851097,
#  0.017788385972380638,
#  0.02960040606558323,
#  0.05679330229759216,
#  0.10352617502212524,
#  0.022318484261631966,
#  -0.025733938440680504,
#  0.014975679107010365,
#  0.023815834894776344,
#  -0.024014851078391075,
#  -0.011209270916879177,
#  -0.010946623049676418,
#  -0.03097260184586048,
#  -0.06991128623485565,
#  0.0193684883415699,
#  -0.05373602360486984,
#  -0.024300523102283478,
#  0.03814404457807541,
#  -8.181569910448161e-07,
#  -0.02765263244509697,
#  -0.01216935645788908,
#  0.04901999980211258,
#  -0.03336353227496147,
#  -0.001970768440514803,
#  0.04831106960773468,
#  0.038648203015327454,
#  0.02383076399564743,
#  -0.018018260598182678,
#  -0.05035623162984848,
#  0.023315798491239548,
#  0.052843399345874786,
#  0.0539836585521698,
#  -0.05859227105975151,
#  0.030107194557785988,
#  0.06523825973272324,
#  -0.01672675833106041,
#  -0.010149565525352955,
#  0.022228650748729706,
#  0.018423154950141907,
#  0.06052364036440849,
#  -0.00912235863506794,
#  -0.0009021089063026011,
#  0.049179207533597946,
#  -0.0004832632257603109,
#  0.01692911796271801,
#  0.05049337446689606,
#  -0.17171695828437805,
#  0.03350980207324028,
#  0.033113233745098114,
#  0.05646190419793129,
#  -0.02481517568230629,
#  0.0257998276501894,
#  0.03808009997010231,
#  0.0036805535200983286,
#  0.011838117614388466,
#  0.02862320840358734,
#  -0.008350204676389694,
#  -0.03063580021262169,
#  0.019523434340953827,
#  -0.049267712980508804,
#  0.012377032078802586,
#  0.024830665439367294,
#  -0.031562093645334244,
#  -0.02341369539499283,
#  0.01798183284699917,
#  -0.016999348998069763,
#  -0.29776009917259216,
#  0.035031117498874664,
#  0.00883905403316021,
#  0.010588391683995724,
#  0.05652102828025818,
#  0.03731372952461243,
#  -0.04001174494624138,
#  0.01459523942321539,
#  -0.03754745051264763,
#  0.007000637240707874,
#  0.04786672443151474,
#  0.04096387326717377,
#  0.02761213667690754,
#  -0.08126047253608704,
#  -0.027220338582992554,
#  0.021834874525666237,
#  0.07597069442272186,
#  -0.02678479254245758,
#  0.05442089959979057,
#  0.04068601131439209,
#  -0.03474884852766991,
#  0.03917146846652031,
#  0.17585816979408264,
#  0.009190769866108894,
#  0.06448390334844589,
#  -0.00927009154111147,
#  -0.006894581951200962,
#  0.08121893554925919,
#  0.052862364798784256,
#  -0.0018575835274532437,
#  0.023477304726839066,
#  -0.02659529261291027,
#  0.0835956484079361,
#  -0.0036451739724725485,
#  -0.02236483432352543,
#  0.026649396866559982,
#  0.017211392521858215,
#  0.003965531010180712,
#  0.013421107083559036,
#  0.017498796805739403,
#  -0.01495313085615635,
#  0.08730889856815338,
#  -0.025027835741639137,
#  -0.004079991951584816,
#  0.03108946420252323,
#  -0.0029842848889529705,
#  -0.027692578732967377,
#  -0.05588167905807495,
#  -0.040536221116781235,
#  0.0740659087896347,
#  -0.014249444007873535,
#  -0.03275374323129654,
#  -0.1468881517648697,
#  -0.04202886298298836,
#  0.040477097034454346,
#  0.007656504400074482,
#  0.026998063549399376,
#  0.007753428071737289,
#  0.05353206396102905,
#  0.019130764529109,
#  -0.04108702018857002,
#  0.017861666157841682,
#  -0.0015399816911667585,
#  -0.0015869749477133155,
#  0.029228949919342995]

# %%
embeddings= [embedding.tolist() for embedding in embeddings]

# %%
colection.add(
    embeddings = embeddings,
    ids = props,
    documents = [f"Wikidata property: {label} ({desc})" for label, desc in zip(labels, descs)],
    metadatas = [
        {"label": label, "desc": desc, "prop": prop.split("/")[-1]} for label, desc, prop in zip(labels, descs, props)
    ]
)

# %%
import datasets

dataset = datasets.load_from_disk("../simple_questions")

# %%
(
    dataset[0]["turns"][2]["utterance"],
    dataset[0]["turns"][2]["relations"],
    dataset[0]["turns"][2]["entities_in_utterance"],
)
# Out:
# ('What were the positions for which Daniel Ermentrout were appointed ?',
#  ['P39'],
#  ['Q5217081'])

# %%
def find_properties_for_entity(entity_id):
    query = (
        "SELECT ?pLabel ?p WHERE { wd:"
        + entity_id
        + ' ?a ?b.  ?p wikibase:directClaim ?a . SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }}'
    )

    url = "https://query.wikidata.org/sparql"
    r = requests.get(url, params={"query": query, "format": "json"})
    data = r.json()
    props = []
    for binding in data["results"]["bindings"]:
        props.append(binding["p"]["value"].split("/")[-1])

    return props


restricted_props = find_properties_for_entity("Q5217081")

# %%
# query
query = "What were the positions for which Daniel Ermentrout were appointed ?"

query_embedding = list(model.embed([query]))[0].tolist()

result = colection.query(query_embedding, where={
    "prop":{
        "$in": restricted_props
    }
})

result
# Out:
# {'ids': [['http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/P69',
#    'http://www.wikidata.org/entity/P937',
#    'http://www.wikidata.org/entity/P8462',
#    'http://www.wikidata.org/entity/P1157',
#    'http://www.wikidata.org/entity/P214',
#    'http://www.wikidata.org/entity/P569',
#    'http://www.wikidata.org/entity/P102',
#    'http://www.wikidata.org/entity/P2163']],
#  'distances': [[0.9757838249206543,
#    1.0132941007614136,
#    1.0224051475524902,
#    1.03183114528656,
#    1.0387098789215088,
#    1.0429688692092896,
#    1.0550448894500732,
#    1.088775873184204,
#    1.1193854808807373,
#    1.119476079940796]],
#  'metadatas': [[{'desc': 'subject currently or formerly holds the object position or public office',
#     'label': 'position held',
#     'prop': 'P39'},
#    {'desc': 'occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39)',
#     'label': 'occupation',
#     'prop': 'P106'},
#    {'desc': 'educational institution attended by subject',
#     'label': 'educated at',
#     'prop': 'P69'},
#    {'desc': 'location where persons or organisations were actively participating in employment, business or other work',
#     'label': 'work location',
#     'prop': 'P937'},
#    {'desc': 'identifier for a politician in the Political Graveyard database',
#     'label': 'Political Graveyard politician ID',
#     'prop': 'P8462'},
#    {'desc': 'identifier for a person on the Biographical Directory of the United States Congress',
#     'label': 'US Congress Bio ID',
#     'prop': 'P1157'},
#    {'desc': 'identifier for the Virtual International Authority File database [format: up to 22 digits]',
#     'label': 'VIAF ID',
#     'prop': 'P214'},
#    {'desc': 'date on which the subject was born',
#     'label': 'date of birth',
#     'prop': 'P569'},
#    {'desc': 'the political party of which a person is or has been a member or otherwise affiliated',
#     'label': 'member of political party',
#     'prop': 'P102'},
#    {'desc': "authority control identifier in WorldCat's “FAST Linked Data” authority file",
#     'label': 'FAST ID',
#     'prop': 'P2163'}]],
#  'embeddings': None,
#  'documents': [['Wikidata property: position held (subject currently or formerly holds the object position or public office)',
#    'Wikidata property: occupation (occupation of a person; see also "field of work" (Property:P101), "position held" (Property:P39))',
#    'Wikidata property: educated at (educational institution attended by subject)',
#    'Wikidata property: work location (location where persons or organisations were actively participating in employment, business or other work)',
#    'Wikidata property: Political Graveyard politician ID (identifier for a politician in the Political Graveyard database)',
#    'Wikidata property: US Congress Bio ID (identifier for a person on the Biographical Directory of the United States Congress)',
#    'Wikidata property: VIAF ID (identifier for the Virtual International Authority File database [format: up to 22 digits])',
#    'Wikidata property: date of birth (date on which the subject was born)',
#    'Wikidata property: member of political party (the political party of which a person is or has been a member or otherwise affiliated)',
#    "Wikidata property: FAST ID (authority control identifier in WorldCat's “FAST Linked Data” authority file)"]],
#  'uris': None,
#  'data': None}
